# %% [markdown]
# # SEABORN
# ## DISTRIBUTION PLOT
# - distplot
# - joinplot => bivariate analysis
# - pairplot  => more than two features analyis

# %%
import seaborn as sns
import pandas as pd

# %%
df = sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # correlation with heatmap
# - to find relation between two features

# %%
df['total_bill'].corr(df['tip'])
# Out:
# 0.6757341092113641

# %%
sns.jointplot(data=df, x='total_bill', y='tip',kind='reg')
# Out:
# d:\Users\odins\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# d:\Users\odins\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.pairplot(df,hue='sex')
# Out:
# d:\Users\odins\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# d:\Users\odins\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1057: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = data.groupby(
# d:\Users\odins\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sex = pd.get_dummies(df['sex'],drop_first=True)
sex
# Out:
#      Female
# 0      True
# 1     False
# 2     False
# 3     False
# 4      True
# ..      ...
# 239   False
# 240    True
# 241   False
# 242   False
# 243    True
#
# [244 rows x 1 columns]

# %%
smoker = pd.get_dummies(df['smoker'],drop_first=True)
smoker
# Out:
#         No
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# ..     ...
# 239   True
# 240  False
# 241  False
# 242   True
# 243   True
#
# [244 rows x 1 columns]

# %%
day = pd.get_dummies(df['day'],drop_first=True)
day
# Out:
#        Fri    Sat    Sun
# 0    False  False   True
# 1    False  False   True
# 2    False  False   True
# 3    False  False   True
# 4    False  False   True
# ..     ...    ...    ...
# 239  False   True  False
# 240  False   True  False
# 241  False   True  False
# 242  False   True  False
# 243  False  False  False
#
# [244 rows x 3 columns]

# %%
time = pd.get_dummies(df['time'],drop_first=True)
time
# Out:
#      Dinner
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# ..      ...
# 239    True
# 240    True
# 241    True
# 242    True
# 243    True
#
# [244 rows x 1 columns]

# %%
df.drop(['sex','day','smoker','time'],axis=1,inplace=True)
df
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
df = pd.concat([df,sex,day,smoker,time],axis=1)
df
# Out:
#      total_bill   tip  size  Female    Fri    Sat    Sun     No  Dinner  \
# 0         16.99  1.01     2    True  False  False   True   True    True
# 1         10.34  1.66     3   False  False  False   True   True    True
# 2         21.01  3.50     3   False  False  False   True   True    True
# 3         23.68  3.31     2   False  False  False   True   True    True
# 4         24.59  3.61     4    True  False  False   True   True    True
# ..          ...   ...   ...     ...    ...    ...    ...    ...     ...
# 239       29.03  5.92     3   False  False   True  False   True    True
# 240       27.18  2.00     2    True  False   True  False  False    True
# 241       22.67  2.00     2   False  False   True  False  False    True
# 242       17.82  1.75     2   False  False   True  False   True    True
# 243       18.78  3.00     2    True  False  False  False   True    True
#
#      Female    Fri    Sat    Sun     No  Dinner
# 0      True  False  False   True   True    True
# ...

# %%
df.corr()
# Out:
#             total_bill       tip      size    Female       Fri       Sat  \
# total_bill    1.000000  0.675734  0.598315 -0.144877 -0.086168  0.054919
# tip           0.675734  1.000000  0.489299 -0.088862 -0.055463 -0.002790
# size          0.598315  0.489299  1.000000 -0.086195 -0.142184 -0.041121
# Female       -0.144877 -0.088862 -0.086195  1.000000  0.071060 -0.053957
# Fri          -0.086168 -0.055463 -0.142184  0.071060  1.000000 -0.216319
# Sat           0.054919 -0.002790 -0.041121 -0.053957 -0.216319  1.000000
# Sun           0.122953  0.125114  0.193054 -0.168106 -0.195451 -0.500682
# No           -0.085721 -0.005929  0.133178  0.002816 -0.244316 -0.155744
# Dinner        0.183118  0.121629  0.103411 -0.205231 -0.058159  0.462709
# Female       -0.144877 -0.088862 -0.086195  1.000000  0.071060 -0.053957
# Fri          -0.086168 -0.055463 -0.142184  0.071060  1.000000 -0.216319
# Sat           0.054919 -0.002790 -0.041121 -0.053957 -0.216319  1.000000
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >
